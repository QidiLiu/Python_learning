# %% [markdown]
# # LaTeX 学习
#
# 本文参考自[如何使用jupyter编写数学公式(译)](https://www.jianshu.com/p/93ccc63e5a1b)、[MarkDown 中使用 LaTeX 数学式
# ](https://www.cnblogs.com/nowgood/p/Latexstart.html)和[希腊字母发音对照表及其latex命令](https://blog.csdn.net/lanchunhui/article/details/49819445)，以及一位日本朋友写的[Jupyter Notebook で数式を美しく書く](https://qiita.com/namoshika/items/63db972bfd1030f8264a)

# %% [markdown]
# ### 上标
#
# ```markdown
# $$x^2$$
# $$e^{2x}$$
# ```
#
# $$x^2$$
# $$e^{2x}$$
#
# ### 下标
#
# ```markdown
# $$x_i$$
# $$_{10}C_5$$
# ```
#
# $$x_i$$
# $$_{10}C_5$$
#
# ### 换行
#
# ```markdown
# $$
# \begin{gather}
# Roses=red\\
# Violets=blue\\
# Sugar=sweet\\
# so=Sugar\\
# (you==so) >>> True
# \end{gather}
# $$
# ```
#
# $$
# \begin{gather}
# Roses=red\\
# Violets=blue\\
# Sugar=sweet\\
# so=Sugar\\
# (you==so) >>> True
# \end{gather}
# $$
#
# ### 命令
#
# ```markdown
# $$\sqrt{2\pi}$$
# ```
#
# $$\sqrt{2\pi}$$
#
# ### 符号
#
# ```markdown
# $$\alpha, \beta, \gamma$$
# $$\Phi, \Lambda, \Gamma$$
# ```
#
# $$\alpha, \beta, \gamma$$
# $$\Phi, \Lambda, \Gamma$$
#
# 这里注意beta的大写形式是B而不是\Beta：
# $$B$$
#
# ```markdown
# $$\times, \pm, \cup, \oplus$$
# $$\sin(kx - \omega t)$$
# $$sin(kx - \omega t)$$
# ```
#
# $$\times, \pm, \cup, \oplus$$
# $$\sin(kx - \omega t)$$
# $$sin(kx - \omega t)$$
#
# ### 头顶标识
#
# ```markdown
# $$\hat x$$
# $$\widehat{abs}$$
# ```
# $$\hat x$$
# $$\widehat{abs}$$
#
# ```markdown
# $$\bar x$$
# ```
# $$\bar x$$
#
# ```markdown
# $$\dot x, \ddot x$$
# ```
# $$\dot x, \ddot x$$
#
# ```markdown
# $$\vec{x}, \overrightarrow{AB}$$
# ```
#
# $$\vec{x}, \overrightarrow{AB}$$
#
# ### 括号
#
# ```markdown
# $$z = \left(\frac{dx}{dy}\right)^\frac{1}{3}$$
# ```
#
# $$z = \left(\frac{dx}{dy}\right)^\frac{1}{3}$$
#
# ```markdown
# $$\langle{\phi}\mid{\psi}\rangle$$
# ```
#
# $$\langle{\phi}\mid{\psi}\rangle$$
#
# ```markdown
# $$
# \left\{
# \begin{align}
# &\dot U_1=-\dot E_1+\dot I_1Z_1\\
# &\dot U_2=\dot E_2-\dot I_2Z_2\\
# &\dot I_1+\dot I_2/k=\dot I_m\\
# &\dot E_1=k\dot E_2\\
# &\dot E_1=-\dot I_mZ_m\\
# &\dot U_2=\dot I_2Z_L
# \end{align}
# \right.
# $$
# ```
#
# $$
# \left\{
# \begin{align}
# &\dot U_1=-\dot E_1+\dot I_1Z_1\\
# &\dot U_2=\dot E_2-\dot I_2Z_2\\
# &\dot I_1+\dot I_2/k=\dot I_m\\
# &\dot E_1=k\dot E_2\\
# &\dot E_1=-\dot I_mZ_m\\
# &\dot U_2=\dot I_2Z_L
# \end{align}
# \right.
# $$
#
# ### 换行
#
# 上面的例子都是用了两个美元符号来标记公式，这样会换行如果两边各用一个就是不换行：
#
# ```markdown
# $$\langle{\phi}\mid{\psi}\rangle$$
# 不换行是这样：$\langle{\phi}\mid{\psi}\rangle$
# ```
#
# $$\langle{\phi}\mid{\psi}\rangle$$
# 不换行是这样：$\langle{\phi}\mid{\psi}\rangle$
#
# ### 求和符号
#
# ```markdown
# $$h_j=\frac{n_i}{\sum_{i=1}^{k}n_i}\centerdot100\,(in\,\%)$$
# ```
#
# $$h_j=\frac{n_i}{\sum_{i=1}^{k}n_i}\centerdot100\,(in\,\%)$$
#
# ### 行列式与矩阵
#
# ```markdown
# $$
#     \boldsymbol{A} =
#         \left(\begin{array}{ccc}
#             a_{0,0} & \cdots & a_{0,x} \\
#             \vdots  & \ddots & \vdots \\
#             a_{y,0} & \cdots & a_{y,x} \\
#         \end{array}\right)
# $$
# ```
#
# $$
#     \boldsymbol{A} =
#         \left(\begin{array}{ccc}
#             a_{0,0} & \cdots & a_{0,x} \\
#             \vdots  & \ddots & \vdots \\
#             a_{y,0} & \cdots & a_{y,x} \\
#         \end{array}\right)
# $$
#
# ```markdown
# $$
#     \boldsymbol{A} =
#         \left[\begin{array}{ccc}
#             a_{0,0} & \cdots & a_{0,x} \\
#             \vdots  & \ddots & \vdots \\
#             a_{y,0} & \cdots & a_{y,x} \\
#         \end{array}\right]
# $$
# ```
#
# $$
#     \boldsymbol{A} =
#         \left[\begin{array}{ccc}
#             a_{0,0} & \cdots & a_{0,x} \\
#             \vdots  & \ddots & \vdots \\
#             a_{y,0} & \cdots & a_{y,x} \\
#         \end{array}\right]
# $$
#
# ### 速查表
# ![](https://upload-images.jianshu.io/upload_images/5798456-33a39b68d3d2825d.png)
